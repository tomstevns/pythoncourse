# %% [markdown]
# # Datetime in Python
#
# This intro to handling *dates* and *times* in Python is based on the documentation of the standard library's `datetime` module https://docs.python.org/3.6/library/datetime.html.
#
# The datetime module supplies classes for manipulating *dates* and *times* in both simple and complex ways. While date and time arithmetic is supported, the focus of the implementation is on efficient attribute extraction for output formatting and manipulation.

# %% [markdown]
# ## Date Objects
#
# A date object represents a date (year, month and day) in an idealized calendar, the current Gregorian calendar indefinitely extended in both directions. January 1 of year 1 is called day number 1, January 2 of year 1 is called day number 2, and so on. This matches the definition of the "proleptic Gregorian" calendar in Dershowitz and Reingold’s book Calendrical Calculations, where it is the base calendar for all computations. See the book for algorithms for converting between proleptic Gregorian ordinals and many other calendar systems. Alternatively, you can have a look at the paper describing what is extended in the book:
# http://www.cs.tau.ac.il/~nachumd/papers/cc-paper.pdf

# %%
from datetime import date


today = date.today()
today
# Out:
# datetime.date(2018, 10, 2)

# %%
today = date(2050, 10, 2)
today
# Out:
# datetime.date(2050, 10, 2)

# %%
next_lecture = date(today.year, 10, 9)
time_to_next_lecture = abs(next_lecture - today)
time_to_next_lecture.days
# Out:
# 7

# %%
from datetime import timedelta
# see the timedelta documentation:
# https://docs.python.org/3.6/library/datetime.html#timedelta-objects

next_lecture = date(today.year, 10, 2) + timedelta(5)
time_to_next_lecture = abs(next_lecture - today)
time_to_next_lecture.days
print(next_lecture)
# Out:
# 2018-10-07

# %%
today.strftime("%d/%m/%Y")
# Out:
# '02/10/2018'

# %%
today.strftime("%A %d. %B %Y")
# Out:
# 'Tuesday 02. October 2018'

# %% [markdown]
# ## Time Objects
#
# A time object represents a (local) time of day, independent of any particular day. In our coure I will not consider times with respect to different time zones. In case you need to add information about which time zone a `time` refers, please read https://docs.python.org/3.4/library/datetime.html#tzinfo-objects.

# %%
from datetime import datetime, date, time


t = time(12, 10, 30)
t.isoformat()
# Out:
# '12:10:30'

# %%
print(t.strftime('%H:%M:%S'))

print('The time is {:%H:%M}.'.format(t))
# Out:
# 12:10:30
# The time is 12:10.

# %% [markdown]
# ## Datetime Objects

# %%
from datetime import datetime, date, time


d = date.today()
t = time(12, 30)
datetime.combine(d, t)
# Out:
# datetime.datetime(2018, 10, 1, 12, 30)

# %%
now = datetime.now()
now
# Out:
# datetime.datetime(2018, 10, 2, 9, 27, 20, 290027)

# %%
datetime.utcnow()
# Out:
# datetime.datetime(2018, 10, 2, 7, 27, 47, 875019)

# %%
ic = now.isocalendar()
week_number = ic[1]
week_number
# Out:
# 40

# %%
now.strftime("%A, %d. %B %Y %I:%M%p")
# Out:
# 'Monday, 01. October 2018 11:55AM'

# %%
'The {1} is {0:%d}, the {2} is {0:%B}, the {3} is {0:%I:%M%p}.'.format(now, "day", "month", "time")
# Out:
# 'The day is 01, the month is October, the time is 11:55AM.'

# %%
d = datetime.strptime('10 Jun 2010', '%d %b %Y')
print(d)
d.strftime('%d-%m-%Y week: %U')
# Out:
# 2010-06-10 00:00:00
# '10-06-2010 week: 23'

# %% [markdown]
# ## Timedeltas
#
# A `timedelta` object represents a duration, the difference between two dates or times.

# %%
from datetime import timedelta


d = timedelta(microseconds=5)
(d.days, d.seconds, d.microseconds)

# %%
timedelta(hours=-5)

# %% [markdown]
# ### Operations with `timedelta`s

# %%
year_as_delta = timedelta(days=365)
another_year_delta = timedelta(weeks=40, days=84, hours=23, minutes=50, seconds=600)  # adds up to 365 days

last_year = datetime.now() - year_as_delta
next_year = datetime.now() - year_as_delta + (2 *another_year_delta)
print(last_year)
print(next_year)

two_year_delta = next_year - last_year
print('The two year difference is equivalent to {} days and {} seconds'.format(
    two_year_delta.days, two_year_delta.total_seconds()))
# Out:
# 2017-10-01 11:56:33.474772
# 2019-10-01 11:56:33.474801
# The two year difference is equivalent to 730 days and 63072000.000029 seconds

# %% [markdown]
# ## Converting Strings to Times and Vice Versa

# %%
from datetime import datetime


datetime.now().isoformat()

# %%
dt = datetime.strptime('21/11/06 16:30', '%d/%m/%y %H:%M')
dt

# %%
dt.strftime('%y-%m-%d %H:%M')

# %% [markdown]
# ### Parsing Arbitrary Dates from Strings
#
# The `dateutil.parser` module offers a generic date/time string parser which is able to parse most known formats to represent a date and/or time.
#
# The module attempts to be forgiving with regards to unlikely input formats, returning a datetime object even for dates which are ambiguous.

# %%
import dateutil.parser


dateutil.parser.parse('21/11-06 16:30')
# Out:
# datetime.datetime(2006, 11, 21, 16, 30)

# %% [markdown]
# # Pandas for Time Series and Data Frames
#
# Pandas is -similar to NumPy- another library offering high-level data structures, which enable fast data analyzis. For us, the most important are probably the types `Series` and `DataFrame`, both of which are introduced in the following.
#
# This tutorial is based on the intro to Pandas: http://pandas.pydata.org/pandas-docs/stable/10min.html

# %%
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# As we will refer to Panda's classes and functions often in code, we usually import the module as `pd`.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## `Series`
#
# A `Series` is a one-dimensional labeled array capable of holding any data type (integers, strings, floating point numbers, Python objects, etc.). The axis labels are collectively referred to as the index.
#
# http://pandas.pydata.org/pandas-docs/stable/dsintro.html#series
#
# You can creating a Series by passing a list of values, letting Pandas create a default integer index.

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %% [markdown]
# For the following example introducing `Series` we will collect some open data from the World Bank, see http://data.worldbank.org/?locations=DK-UY. The this dataset includes a plethora of interesting data. However, for this example we will focus on the *CO2 emissions (metric tons per capita)*.
#
# First, we have to download the data. We do this by writing the response to a request to the World Bank API into a file. As denoted in the response header, we receive a ZIP file.

# %%
import requests


url = 'http://api.worldbank.org/v2/en/country/DNK;URY'
parameters = {'downloadformat': 'csv'}
# Out:
# {'Date': 'Mon, 01 Oct 2018 09:57:29 GMT', 'Content-Type': 'application/zip', 'Content-Length': '681711', 'Connection': 'keep-alive', 'Content-Disposition': 'attachment; filename=API_Download_DS2_en_csv_v2_10165961.zip', 'X-Powered-By': 'ASP.NET', 'Set-Cookie': 'TS019266c8=017189f94716df1618444194ff5bfab9393ecf9e5d5365f3f802b93f51a36e08c03586a735; Path=/', 'Strict-Transport-Security': 'max-age=31536000; includeSubDomains', 'X-XSS-Protection': '1; mode=block', 'X-Content-Type-Options': 'nosniff', 'X-Frame-Options': 'deny'}
# Downloaded API_Download_DS2_en_csv_v2_10165961.zip

# %% [markdown]
# **TODO**: Use the requests module to get the contents of the remote file and print the header of the HTTP response.

# %%
import requests


url = 'http://api.worldbank.org/v2/en/country/DNK;URY'

response = requests.get(url, params={'downloadformat': 'csv'})
print(response.headers)

fname = response.headers['Content-Disposition'].split('=')[1]

if response.ok:  # status_code == 200:
    with open(fname, 'wb') as f: # wb gemmer som binary fil.
        f.write(response.content)   

print('Downloaded {}'.format(fname))
# Out:
# {'Date': 'Tue, 02 Oct 2018 09:27:12 GMT', 'Content-Type': 'application/zip', 'Content-Length': '681711', 'Connection': 'keep-alive', 'Content-Disposition': 'attachment; filename=API_Download_DS2_en_csv_v2_10165961.zip', 'X-Powered-By': 'ASP.NET', 'Set-Cookie': 'TS01fa65e4=01359ee9767d2353417f01e543607d85077b1d7ae99c7ad2b80b0c0c5bf60ab113882a749f; Path=/', 'Strict-Transport-Security': 'max-age=31536000; includeSubDomains', 'X-XSS-Protection': '1; mode=block', 'X-Content-Type-Options': 'nosniff', 'X-Frame-Options': 'deny'}
# Downloaded API_Download_DS2_en_csv_v2_10165961.zip

# %%
fname = response.headers['Content-Disposition'].split('=')[1]

# %% [markdown]
# **TODO**: Save the response's contents into a binary file.

# %%
# %%bash
# ls -ltrh | tail

# %% [markdown]
# You can resort to the standard libraries `zipfile` module to uncompress the downloaded file.

# %% [markdown]
# **TODO** extract the downloaded file with help of the `zipfile` module.

# %%
import zipfile

zipfile.ZipFile(fname, 'r').extractall('.')

# %%
# %%bash
#
# ls -ltrh | tail

# %% [markdown]
# Additionally, you can make use of the `glob` module to glob for certain file patterns. We will store the filename of the CSV file we are interested in, in a variable called `local_file`.

# %%
from glob import glob


local_file = glob('./API_Download*.csv')[0]
local_file
# Out:
# './API_Download_DS2_en_csv_v2_10165961.csv'

# %% [markdown]
# ## A small detour...
#
# ### Collecting information on the CLI
#
# To see the header of the file that is of our interest, we can use the `head` command.

# %%
# %%bash
# head ./API_Download_*.csv
# Out:
# ﻿"Data Source","World Development Indicators",
#
# "Last Updated Date","2018-09-21",
#
# "Country Name","Country Code","Indicator Name","Indicator Code","1960","1961","1962","1963","1964","1965","1966","1967","1968","1969","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017",
# "Denmark","DNK","Presence of peace keepers (number of troops, police, and military observers in mandate)","VC.PKP.TOTL.UN","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","",
# "Denmark","DNK","Intentional homicides (per 100,000 people)","VC.IHR.PSRC.P5","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","1.14649009700071","1.31298198569687","1.6674334334046","0.924589534137072","0.977353957005448","1.08589951984519","0.970500154720121","1.04228688164702","1.20661566951948","0.795889361013748","0.977552805373663","0.532666899693129","0.712985495132777","0.982211959521954","0.850455998220918","0.75609684088338","0.823948529726541","0.837691109423847","0.851393367326396","1.2888613774856","0.984408550642986","0.980681382327848","",
# "Denmark","DNK","Intentional homicides, male (per 100,000 male)","VC.IHR.PSRC.MA.P5","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","1.14641359050158","1.24058601466145","1.64237199424869","1.3584321686474","1.01029378296604","1.36363957976745","0.716769337695244","0.844421193056963","1.35078836511616","1.15642990895291","0.725614895132321","1.11852504792519","1.11242848161407","1.24931376979359","1.49165737340446","1.16656909906929","1.16215223436344","",
# "Denmark","DNK","Intentional homicides, female (per 100,000 female)","VC.IHR.PSRC.FE.P5","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","1.02662874165866","0.705848822460537","0.454071346697479","1.05775461333346","0.585583990657475","0.598668828961911","0.351896735538925","0.583844488789311","0.619810115104314","0.549366765468079","0.786116889864309","0.533548839637984","0.566579260012075","0.458347171892177","1.08838378518815","0.804227579621153","0.801182612619428","",
# "Denmark","DNK","Internally displaced persons, total displaced by conflict and violence (number of people)","VC.IDP.TOCV","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","",

# %% [markdown]
# We can see that the actual CSV header is on line five. To extract only the header row, we can use the stream editor *sed*, see `man sed`. The argument `'5!d'` tells `sed`, that we are only interested in the fifth line.

# %%
# %%bash
# sed '5!d' API_Download_DS2_en_csv_v2_10165961.csv
# Out:
# "Country Name","Country Code","Indicator Name","Indicator Code","1960","1961","1962","1963","1964","1965","1966","1967","1968","1969","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017",

# %% [markdown]
# To get the two lines -one for Denmark and one for Uruguay repectively- holding the CO2 emission in tons, we can use the grep command, see `man grep`.

# %%
# %%bash
# grep 'CO2 emissions (metric tons per capita)' API_Download_DS2_en_csv_v2_101659613.csv
# Out:
# grep: API_Download_DS2_en_csv_v2_101659613.csv: No such file or directory

# %% [markdown]
# ### Executing OS Commands from Python
#
#
# With the help of the `subprocess` module allows us to execute shell commands and to read what the process was writing to standard out and standard error.

# %%
import subprocess


cmd = 'sed 5!d {}'.format(local_file).split()
out, err = subprocess.Popen(cmd, stdout=subprocess.PIPE, 
                            stderr=subprocess.STDOUT).communicate()
# Since we are getting the output as a byte literal, we have to decode it into string
header_cols = out.splitlines()[0].decode('UTF-8').split(',')
header_cols = [h.replace('"', '') for h in header_cols]
header_cols
# Out:
# ['Country Name',
#  'Country Code',
#  'Indicator Name',
#  'Indicator Code',
#  '1960',
#  '1961',
#  '1962',
#  '1963',
#  '1964',
#  '1965',
#  '1966',
#  '1967',
#  '1968',
#  '1969',
#  '1970',
#  '1971',
#  '1972',
#  '1973',
#  '1974',
#  '1975',
#  '1976',
#  '1977',
#  '1978',
#  '1979',
#  '1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '']

# %%
# %%bash
# ls -ltr API_Download_DS2_en_csv_v2_10165961.csv
# Out:
# -rw-r--r--  1 rhp  staff  1751157 Oct  1 11:57 API_Download_DS2_en_csv_v2_10165961.csv

# %% [markdown]
# Now, let's get in a similar way the line of the CSV file containing the time series corresponding to Danmark's and Uruguay's CO2 emissions per person.

# %%
import subprocess


cmd = ['grep', 'CO2 emissions (metric tons per capita)', local_file]
out, err = subprocess.Popen(cmd, stdout=subprocess.PIPE, 
                            stderr=subprocess.STDOUT).communicate()
lines = out.decode('UTF-8').splitlines()
lines = [l.split(',') for l in lines]
lines = [[c.replace('"', '') for c in l] for l in lines]
lines
# Out:
# [['Denmark',
#   'DNK',
#   'CO2 emissions (metric tons per capita)',
#   'EN.ATM.CO2E.PC',
#   '6.50268309283578',
#   '6.88126015490644',
#   '7.9451073610821',
#   '8.68983130048716',
#   '9.14639293937068',
#   '9.31657600359066',
#   '10.4490116586529',
#   '10.1493005475918',
#   '10.9613147942099',
#   '12.1429748602781',
#   '12.5996564651087',
#   '11.4972271507917',
#   '11.9488346011977',
#   '11.801611792919',
#   '10.9167686263068',
#   '11.0237664584528',
#   '11.8549028939028',
#   '12.1545851471744',
#   '11.9739262277225',
#   '12.3121966244144',
#   '11.7840138262008',
#   '10.1119423880012',
#   '10.491964531704',
#   '9.81084223305764',
#   '9.9501332161102',
#   '11.7474430895414',
#   '11.5032965311821',
#   '11.3793050315349',
#   '10.7432506302739',
#   '9.5050900188092',
#   '9.77069869920651',
#   '11.6933114849006',
#   '10.5045544990979',
#   '10.9982550300388',
#   '11.7169488953513',
#   '10.9245408267288',
#   '13.7146519315518',
#   '11.6476885201886',
#   '11.2273041516574',
#   '10.3626636406223',
#   '9.61317555419716',
#   '9.87509234839328',
#   '9.68193192955788',
#   '10.3882734936947',
#   '9.36270101912787',
#   '8.69007693057132',
#   '10.1129141598949',
#   '9.20201511030611',
#   '8.54335109757298',
#   '8.05889560110771',
#   '8.40721667045503',
#   '7.29638320804399',
#   '6.51480084670286',
#   '6.86256503195408',
#   '5.9357124821143',
#   '',
#   '',
#   '',
#   ''],
#  ['Uruguay',
#   'URY',
#   'CO2 emissions (metric tons per capita)',
#   'EN.ATM.CO2E.PC',
#   '1.7015832424386',
#   '1.60272350088852',
#   '1.54065748628877',
#   '1.6392844524879',
#   '1.71009908493691',
#   '2.04951796913533',
#   '1.98509076979974',
#   '1.77610139002572',
#   '1.76030336164315',
#   '2.002057211223',
#   '2.04374541560387',
#   '2.06102609047394',
#   '2.15358864749513',
#   '2.04654827412821',
#   '2.01264558337633',
#   '2.10936861787905',
#   '2.07520089363486',
#   '1.97782265615019',
#   '1.99672805589496',
#   '2.16776731400269',
#   '2.00216340201483',
#   '1.83160342837362',
#   '1.64962011074095',
#   '1.28380511208648',
#   '1.15304254263369',
#   '1.0945330999486',
#   '1.04891096713403',
#   '1.16744153869256',
#   '1.56640010635043',
#   '1.5800590096938',
#   '1.28404409147428',
#   '1.45413195830207',
#   '1.63889307115541',
#   '1.40534555426025',
#   '1.27020680551985',
#   '1.42367846231895',
#   '1.67542160106033',
#   '1.69840660835644',
#   '1.72760589015406',
#   '2.03222476655311',
#   '1.59763853615135',
#   '1.52979814571415',
#   '1.38844206020062',
#   '1.38271795749205',
#   '1.68783031536995',
#   '1.7366803463543',
#   '1.99585265035606',
#   '1.79740854156056',
#   '2.46668222502883',
#   '2.39686388095475',
#   '1.89304338677963',
#   '2.29294186241591',
#   '2.55961960411296',
#   '2.22623587700135',
#   '1.97315082177576',
#   '',
#   '',
#   '',
#   '']]

# %% [markdown]
# As in Pandas `Series` are one-dimensional labeled arrays, we are now ready to go to create two time series of CO2 emissions for Danmark and Uruguay repectively.

# %%
print(header_cols)
print(lines)
# Out:
# ['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code', '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '']
# [['Denmark', 'DNK', 'CO2 emissions (metric tons per capita)', 'EN.ATM.CO2E.PC', '6.50268309283578', '6.88126015490644', '7.9451073610821', '8.68983130048716', '9.14639293937068', '9.31657600359066', '10.4490116586529', '10.1493005475918', '10.9613147942099', '12.1429748602781', '12.5996564651087', '11.4972271507917', '11.9488346011977', '11.801611792919', '10.9167686263068', '11.0237664584528', '11.8549028939028', '12.1545851471744', '11.9739262277225', '12.3121966244144', '11.7840138262008', '10.1119423880012', '10.491964531704', '9.81084223305764', '9.9501332161102', '11.7474430895414', '11.5032965311821', '11.3793050315349', '10.7432506302739', '9.5050900188092', '9.77069869920651', '11.6933114849006', '10.5045544990979', '10.9982550300388', '11.7169488953513', '10.9245408267288', '13.7146519315518', '11.6476885201886', '11.2273041516574', '10.3626636406223', '9.61317555419716', '9.87509234839328', '9.68193192955788', '10.3882734936947', '9.36270101912787', '8.69007693057132', '10.1129141598949', '9.20201511030611', '8.54335109757298', '8.05889560110771', '8.40721667045503', '7.29638320804399', '6.51480084670286', '6.86256503195408', '5.9357124821143', '', '', '', ''], ['Uruguay', 'URY', 'CO2 emissions (metric tons per capita)', 'EN.ATM.CO2E.PC', '1.7015832424386', '1.60272350088852', '1.54065748628877', '1.6392844524879', '1.71009908493691', '2.04951796913533', '1.98509076979974', '1.77610139002572', '1.76030336164315', '2.002057211223', '2.04374541560387', '2.06102609047394', '2.15358864749513', '2.04654827412821', '2.01264558337633', '2.10936861787905', '2.07520089363486', '1.97782265615019', '1.99672805589496', '2.16776731400269', '2.00216340201483', '1.83160342837362', '1.64962011074095', '1.28380511208648', '1.15304254263369', '1.0945330999486', '1.04891096713403', '1.16744153869256', '1.56640010635043', '1.5800590096938', '1.28404409147428', '1.45413195830207', '1.63889307115541', '1.40534555426025', '1.27020680551985', '1.42367846231895', '1.67542160106033', '1.69840660835644', '1.72760589015406', '2.03222476655311', '1.59763853615135', '1.52979814571415', '1.38844206020062', '1.38271795749205', '1.68783031536995', '1.7366803463543', '1.99585265035606', '1.79740854156056', '2.46668222502883', '2.39686388095475', '1.89304338677963', '2.29294186241591', '2.55961960411296', '2.22623587700135', '1.97315082177576', '', '', '', '']]

# %% [markdown]
# Since our data and the corresponding indexes are still all strings we have to convert them to floats and integers repectively. We do so using two different mechanisms. Once, creation of typed NumPy arrays and on the other hand via a Pandas method `convert_objects`, which converts strings to numerical values of a suitable type.

# %% [markdown]
# **TODO**: Create a Pandas `Series` object corrsesponding to the numerical values for Danmark.
#
# Hint: Pandas can convert strings to numbers with the `to_numeric` function.

# %%
# Out:
# API_Download_DS2_en_csv_v2_10165961.zip

# %% [markdown]
# **TODO**: Create a plot for that timeseries.

# %% [markdown]
# **TODO**: Now, do the same as above with the time series for the corresponding Uruguaian time series.

# %% [markdown]
# # `DataFrame`
#
# Since `Series` are one-dimensional arrays, we have to create a `DataFrame` if we wanted to combine our two previous `Series` objects `ts_dk` and `ts_ur`.Since `Series` are one-dimensional arrays, we have to create a `DataFrame` if we wanted to combine our two previous `Series` objects `ts_dk` and `ts_ur`.
#
# A `DataFrame` is a 2-dimensional labeled data structure with columns of potentially different types. You can think of it like a spreadsheet or SQL table, or a dict of Series objects.
#
# In the following we concatenate two `Series`to form a `DataFrame`.

# %% [markdown]
# **TODO**: Use Pandas' `concat` function to create a `DataFrame` object out of the two series and plot it.

# %% [markdown]
# More information on `DataFrame`s can be found here:
# http://pandas.pydata.org/pandas-docs/stable/dsintro.html#dataframe
#
# Similar to, we can create `DataFrame`s by giving the data for the values and indexes explicitely.

# %%
dates = pd.date_range('20180302', periods=6)
df = pd.DataFrame(np.random.randn(6,4), index=dates, 
                  columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2018-03-02  0.453305 -0.250037  0.421138  1.732941
# 2018-03-03 -1.559631  0.010236 -0.350044 -0.526902
# 2018-03-04  0.211961 -0.172763 -0.314271  0.063565
# 2018-03-05 -1.300270 -0.126585  0.443121 -0.327540
# 2018-03-06 -0.009488  0.361025 -0.428788  0.315673
# 2018-03-07  0.892047 -0.885244 -1.025394  0.639099

# %% [markdown]
# But since we do not want to work on random example data. We will have a look on the military expenditures of some countries in the world. We will use this data to exemplify usage of Pandas' `DataFrame` methods.
#
# Again, we will receive the data from the World Bank.
# http://data.worldbank.org/indicator/MS.MIL.XPND.CN?locations=DK-CN-US-RU

# %%
import requests


url = 'http://api.worldbank.org/v2/en/indicator/MS.MIL.XPND.CN'

response = requests.get(url, params={'downloadformat': 'csv'})
fname = response.headers['Content-Disposition'].split('=')[1]

if response.ok:  # status_code == 200:
    with open(fname, 'wb') as f:
        f.write(response.content)   

print(f'Downloaded {fname}')
# Out:
# Downloaded API_MS.MIL.XPND.CN_DS2_en_csv_v2_10151849.zip

# %%
import os
import zipfile


zipfile.ZipFile(fname, 'r').extractall('.')
os.remove(fname)

# %%
# %%bash
# ls -ltr | tail
# Out:
# -rw-r--r--   1 rhp  staff      3729 Sep 25 21:56 intro_plotting.py
# -rw-r--r--   1 rhp  staff    681711 Oct  1 11:57 API_Download_DS2_en_csv_v2_10165961.zip
# -rw-r--r--   1 rhp  staff    938819 Oct  1 11:57 Metadata_Indicator_API_Download_DS2_en_csv_v2_10165961.csv
# -rw-r--r--   1 rhp  staff       192 Oct  1 11:57 Metadata_Country_API_Download_DS2_en_csv_v2_10165961.csv
# -rw-r--r--   1 rhp  staff   1751157 Oct  1 11:57 API_Download_DS2_en_csv_v2_10165961.csv
# -rw-r--r--   1 rhp  staff       555 Oct  2 09:51 Untitled.ipynb
# -rw-r--r--   1 rhp  staff    297193 Oct  2 09:59 16-Intro to Pandas.ipynb
# -rw-r--r--   1 rhp  staff      1648 Oct  2 10:00 Metadata_Indicator_API_MS.MIL.XPND.CN_DS2_en_csv_v2_10151849.csv
# -rw-r--r--   1 rhp  staff     39350 Oct  2 10:00 Metadata_Country_API_MS.MIL.XPND.CN_DS2_en_csv_v2_10151849.csv
# -rw-r--r--   1 rhp  staff    137239 Oct  2 10:00 API_MS.MIL.XPND.CN_DS2_en_csv_v2_10151849.csv

# %%
from glob import glob


milit_files = glob('./*MIL*.csv')
expenditure_csv = milit_files[0]
expenditure_csv
# Out:
# './API_MS.MIL.XPND.CN_DS2_en_csv_v2_10151849.csv'

# %%
# %%bash
# head ./API_MS.MIL.XPND.CN_DS2_en_csv_v2_10151849.csv
# Out:
# ﻿"Data Source","World Development Indicators",
#
# "Last Updated Date","2018-09-21",
#
# "Country Name","Country Code","Indicator Name","Indicator Code","1960","1961","1962","1963","1964","1965","1966","1967","1968","1969","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017",
# "Aruba","ABW","Military expenditure (current LCU)","MS.MIL.XPND.CN","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","",
# "Afghanistan","AFG","Military expenditure (current LCU)","MS.MIL.XPND.CN","","","","","","","","","","","1282500000","","","1457750000","1562500000","1834000000","2353000000","2673250000","","","","","","","","","","","","","","","","","","","","","","","","","","","5986000000","6074333333.33333","6557500000","10970666666.6667","12086666666.6667","12675333333.3333","13849666666.6667","15230500000","12149000000","12027666666.6667","15356000000","12199166666.6667","12614833333.3333","13020833333.3333",
# "Angola","AGO","Military expenditure (current LCU)","MS.MIL.XPND.CN","","","","","","","","","","","","","","","","","","","10.27","15.1","14.88","18.516","20","23.295","31.9","34.3","34.6","44.5","43.961","58.297","52.391","56.82","199.66","4720.2","35410.9","643124","20451600","104621000","66889400","2976540000","5859850000","8917990000","19096100000","49987800000","68297900000","118977000000","158350000000","155900000000","237375000000","262671000000","321743000000","341875000000","395680000000","587869000000","673000000000","433215000000","462209000000","508175000000",
# "Albania","ALB","Military expenditure (current LCU)","MS.MIL.XPND.CN","","","","","","","","","","","","","","","","653000000","783000000","805000000","825000000","885000000","940000000","940000000","935000000","910000000","1010000000","953000000","978000000","1011000000","955000000","965000000","990000000","950000000","2368000000","4010000000","4698000000","4719000000","4777000000","4442000000","5067000000","5891000000","6519000000","7638000000","8220000000","9279000000","10372800000","10999800000","13831000000","17619000000","21450000000","17356000000","19321000000","19877000000","19820000000","19022000000","18788000000","16671000000","16250000000","19352000000",
# "Andorra","AND","Military expenditure (current LCU)","MS.MIL.XPND.CN","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","",

# %% [markdown]
# Now, we use Pandas' `read_csv` function to read the downloaded CSV file directly. Note that we have to skip the first four rows as they do not contain data we are interested in, see keyword argument `skiprows=4`.
#
# Reading the CSV file like this returns a `DataFrame` directly.

# %%
import pandas as pd


expenditures = pd.read_csv(expenditure_csv, skiprows=4)
expenditures
# Out:
#                                           Country Name Country Code  \
# 0                                                Aruba          ABW
# 1                                          Afghanistan          AFG
# 2                                               Angola          AGO
# 3                                              Albania          ALB
# 4                                              Andorra          AND
# 5                                           Arab World          ARB
# 6                                 United Arab Emirates          ARE
# 7                                            Argentina          ARG
# 8                                              Armenia          ARM
# 9                                       American Samoa          ASM
# 10                                 Antigua and Barbuda          ATG
# 11                                           Australia          AUS
# 12                                             Austria          AUT
# 13                                          Azerbaijan          AZE
# 14                                             Burundi          BDI
# 15                                             Belgium          BEL
# 16                                               Benin          BEN
# 17                                        Burkina Faso          BFA
# 18                                          Bangladesh          BGD
# 19                                            Bulgaria          BGR
# 20                                             Bahrain          BHR
# 21                                        Bahamas, The          BHS
# 22                              Bosnia and Herzegovina          BIH
# 23                                             Belarus          BLR
# 24                                              Belize          BLZ
# 25                                             Bermuda          BMU
# 26                                             Bolivia          BOL
# 27                                              Brazil          BRA
# 28                                            Barbados          BRB
# 29                                   Brunei Darussalam          BRN
# ..                                                 ...          ...
# 234  Latin America & the Caribbean (IDA & IBRD coun...          TLA
# 235                                        Timor-Leste          TLS
# 236  Middle East & North Africa (IDA & IBRD countries)          TMN
# 237                                              Tonga          TON
# 238                            South Asia (IDA & IBRD)          TSA
# 239          Sub-Saharan Africa (IDA & IBRD countries)          TSS
# 240                                Trinidad and Tobago          TTO
# 241                                            Tunisia          TUN
# 242                                             Turkey          TUR
# 243                                             Tuvalu          TUV
# 244                                           Tanzania          TZA
# 245                                             Uganda          UGA
# 246                                            Ukraine          UKR
# 247                                Upper middle income          UMC
# 248                                            Uruguay          URY
# 249                                      United States          USA
# 250                                         Uzbekistan          UZB
# 251                     St. Vincent and the Grenadines          VCT
# 252                                      Venezuela, RB          VEN
# 253                             British Virgin Islands          VGB
# 254                              Virgin Islands (U.S.)          VIR
# 255                                            Vietnam          VNM
# 256                                            Vanuatu          VUT
# 257                                              World          WLD
# 258                                              Samoa          WSM
# 259                                             Kosovo          XKX
# 260                                        Yemen, Rep.          YEM
# 261                                       South Africa          ZAF
# 262                                             Zambia          ZMB
# 263                                           Zimbabwe          ZWE
#
#                          Indicator Name  Indicator Code          1960  \
# 0    Military expenditure (current LCU)  MS.MIL.XPND.CN           NaN
# 1    Military expenditure (current LCU)  MS.MIL.XPND.CN           NaN
# 2    Military expenditure (current LCU)  MS.MIL.XPND.CN           NaN
# 3    Military expenditure (current LCU)  MS.MIL.XPND.CN           NaN
# 4    Military expenditure (current LCU)  MS.MIL.XPND.CN           NaN
# 5    Military expenditure (current LCU)  MS.MIL.XPND.CN           NaN
# 6    Military expenditure (current LCU)  MS.MIL.XPND.CN           NaN
# 7    Military expenditure (current LCU)  MS.MIL.XPND.CN  1.550000e-03
# 8    Military expenditure (current LCU)  MS.MIL.XPND.CN           NaN
# 9    Military expenditure (current LCU)  MS.MIL.XPND.CN           NaN
# 10   Military expenditure (current LCU)  MS.MIL.XPND.CN           NaN
# 11   Military expenditure (current LCU)  MS.MIL.XPND.CN  4.105000e+08
# 12   Military expenditure (current LCU)  MS.MIL.XPND.CN  1.730000e+08
# 13   Military expenditure (current LCU)  MS.MIL.XPND.CN           NaN
# 14   Military expenditure (current LCU)  MS.MIL.XPND.CN           NaN
# 15   Military expenditure (current LCU)  MS.MIL.XPND.CN  4.749900e+08
# 16   Military expenditure (current LCU)  MS.MIL.XPND.CN  3.190000e+08
# 17   Military expenditure (current LCU)  MS.MIL.XPND.CN  3.110000e+08
# 18   Military expenditure (current LCU)  MS.MIL.XPND.CN           NaN
# 19   Military expenditure (current LCU)  MS.MIL.XPND.CN           NaN
# 20   Military expenditure (current LCU)  MS.MIL.XPND.CN           NaN
# 21   Military expenditure (current LCU)  MS.MIL.XPND.CN           NaN
# 22   Military expenditure (current LCU)  MS.MIL.XPND.CN           NaN
# 23   Military expenditure (current LCU)  MS.MIL.XPND.CN           NaN
# 24   Military expenditure (current LCU)  MS.MIL.XPND.CN           NaN
# 25   Military expenditure (current LCU)  MS.MIL.XPND.CN           NaN
# 26   Military expenditure (current LCU)  MS.MIL.XPND.CN           NaN
# 27   Military expenditure (current LCU)  MS.MIL.XPND.CN  3.100000e-05
# 28   Military expenditure (current LCU)  MS.MIL.XPND.CN           NaN
# 29   Military expenditure (current LCU)  MS.MIL.XPND.CN           NaN
# ..                                  ...             ...           ...
# 234  Military expenditure (current LCU)  MS.MIL.XPND.CN           NaN
# 235  Military expenditure (current LCU)  MS.MIL.XPND.CN           NaN
# 236  Military expenditure (current LCU)  MS.MIL.XPND.CN           NaN
# 237  Military expenditure (current LCU)  MS.MIL.XPND.CN           NaN
# 238  Military expenditure (current LCU)  MS.MIL.XPND.CN           NaN
# 239  Military expenditure (current LCU)  MS.MIL.XPND.CN           NaN
# 240  Military expenditure (current LCU)  MS.MIL.XPND.CN           NaN
# 241  Military expenditure (current LCU)  MS.MIL.XPND.CN  6.700000e+06
# 242  Military expenditure (current LCU)  MS.MIL.XPND.CN  2.405000e+03
# 243  Military expenditure (current LCU)  MS.MIL.XPND.CN           NaN
# 244  Military expenditure (current LCU)  MS.MIL.XPND.CN           NaN
# 245  Military expenditure (current LCU)  MS.MIL.XPND.CN           NaN
# 246  Military expenditure (current LCU)  MS.MIL.XPND.CN           NaN
# 247  Military expenditure (current LCU)  MS.MIL.XPND.CN           NaN
# 248  Military expenditure (current LCU)  MS.MIL.XPND.CN           NaN
# 249  Military expenditure (current LCU)  MS.MIL.XPND.CN  4.538000e+10
# 250  Military expenditure (current LCU)  MS.MIL.XPND.CN           NaN
# 251  Military expenditure (current LCU)  MS.MIL.XPND.CN           NaN
# 252  Military expenditure (current LCU)  MS.MIL.XPND.CN  7.850000e+05
# 253  Military expenditure (current LCU)  MS.MIL.XPND.CN           NaN
# 254  Military expenditure (current LCU)  MS.MIL.XPND.CN           NaN
# 255  Military expenditure (current LCU)  MS.MIL.XPND.CN           NaN
# 256  Military expenditure (current LCU)  MS.MIL.XPND.CN           NaN
# 257  Military expenditure (current LCU)  MS.MIL.XPND.CN           NaN
# 258  Military expenditure (current LCU)  MS.MIL.XPND.CN           NaN
# 259  Military expenditure (current LCU)  MS.MIL.XPND.CN           NaN
# 260  Military expenditure (current LCU)  MS.MIL.XPND.CN           NaN
# 261  Military expenditure (current LCU)  MS.MIL.XPND.CN  5.000000e+07
# 262  Military expenditure (current LCU)  MS.MIL.XPND.CN           NaN
# 263  Military expenditure (current LCU)  MS.MIL.XPND.CN           NaN
#
#              1961          1962          1963          1964          1965  \
# 0             NaN           NaN           NaN           NaN           NaN
# 1             NaN           NaN           NaN           NaN           NaN
# 2             NaN           NaN           NaN           NaN           NaN
# 3             NaN           NaN           NaN           NaN           NaN
# 4             NaN           NaN           NaN           NaN           NaN
# 5             NaN           NaN           NaN           NaN           NaN
# 6             NaN           NaN           NaN           NaN           NaN
# 7    2.140000e-03  2.660000e-03  3.360000e-03  3.450000e-03  4.280000e-03
# 8             NaN           NaN           NaN           NaN           NaN
# 9             NaN           NaN           NaN           NaN           NaN
# 10            NaN           NaN           NaN           NaN           NaN
# 11   4.205000e+08  4.370000e+08  4.940000e+08  5.855000e+08  7.030000e+08
# 12   1.720000e+08  1.890000e+08  2.380000e+08  3.110000e+08  2.700000e+08
# 13            NaN           NaN           NaN           NaN           NaN
# 14            NaN  4.210000e+08  5.060000e+07  5.810000e+07  1.817000e+08
# 15   4.849040e+08  5.233300e+08  5.510700e+08  6.160900e+08  6.206300e+08
# 16   5.330000e+08  6.700000e+08  7.260000e+08  9.320000e+08  9.790000e+08
# 17   4.030000e+08  1.201000e+09  1.294000e+09  1.313000e+09  8.600000e+08
# 18            NaN           NaN           NaN           NaN           NaN
# 19            NaN           NaN           NaN           NaN           NaN
# 20            NaN           NaN           NaN           NaN           NaN
# 21            NaN           NaN           NaN           NaN           NaN
# 22            NaN           NaN           NaN           NaN           NaN
# 23            NaN           NaN           NaN           NaN           NaN
# 24            NaN           NaN           NaN           NaN           NaN
# 25            NaN           NaN           NaN           NaN           NaN
# 26   5.863277e+01  6.172395e+01  7.608299e+01           NaN           NaN
# 27   4.000000e-05  6.500000e-05  1.100000e-04  1.920000e-04  5.200000e-04
# 28            NaN           NaN           NaN           NaN           NaN
# 29            NaN           NaN           NaN           NaN           NaN
# ..            ...           ...           ...           ...           ...
# 234           NaN           NaN           NaN           NaN           NaN
# 235           NaN           NaN           NaN           NaN           NaN
# 236           NaN           NaN           NaN           NaN           NaN
# 237           NaN           NaN           NaN           NaN           NaN
# 238           NaN           NaN           NaN           NaN           NaN
# 239           NaN           NaN           NaN           NaN           NaN
# 240           NaN           NaN           NaN           NaN           NaN
# 241  7.800000e+06  6.000000e+06  6.400000e+06  7.800000e+06  6.700000e+06
# 242  2.718000e+03  2.980000e+03  3.157000e+03  3.443000e+03  3.821000e+03
# 243           NaN           NaN           NaN           NaN           NaN
# 244           NaN           NaN           NaN           NaN           NaN
# 245           NaN  5.200000e+04  1.950000e+05  3.920000e+05  7.670000e+05
# 246           NaN           NaN           NaN           NaN           NaN
# 247           NaN           NaN           NaN           NaN           NaN
# 248           NaN           NaN           NaN           NaN           NaN
# 249  4.780800e+10  5.238100e+10  5.229500e+10  5.121300e+10  5.182700e+10
# 250           NaN           NaN           NaN           NaN           NaN
# 251           NaN           NaN           NaN           NaN           NaN
# 252  3.840000e+05  6.830000e+05  8.220000e+05  8.720000e+05  1.000000e+06
# 253           NaN           NaN           NaN           NaN           NaN
# 254           NaN           NaN           NaN           NaN           NaN
# 255           NaN           NaN           NaN           NaN           NaN
# 256           NaN           NaN           NaN           NaN           NaN
# 257           NaN           NaN           NaN           NaN           NaN
# 258           NaN           NaN           NaN           NaN           NaN
# 259           NaN           NaN           NaN           NaN           NaN
# 260           NaN           NaN           NaN           NaN           NaN
# 261  8.125000e+07  1.330000e+08  1.350000e+08  1.940000e+08  2.067500e+08
# 262           NaN           NaN           NaN           NaN           NaN
# 263           NaN           NaN           NaN           NaN  1.560000e+07
#
#         ...               2009          2010          2011          2012  \
# 0       ...                NaN           NaN           NaN           NaN
# 1       ...       1.267533e+10  1.384967e+10  1.523050e+10  1.214900e+10
# 2       ...       2.626710e+11  3.217430e+11  3.418750e+11  3.956800e+11
# 3       ...       1.735600e+10  1.932100e+10  1.987700e+10  1.982000e+10
# 4       ...                NaN           NaN           NaN           NaN
# 5       ...                NaN           NaN           NaN           NaN
# 6       ...       5.081400e+10  6.428600e+10  7.044500e+10  6.986600e+10
# 7       ...       1.106300e+10  1.354100e+10  1.665400e+10  2.070300e+10
# 8       ...       1.306000e+11  1.476000e+11  1.456000e+11  1.529000e+11
# 9       ...                NaN           NaN           NaN           NaN
# 10      ...                NaN           NaN           NaN           NaN
# 11      ...       2.431050e+10  2.531100e+10  2.578500e+10  2.532000e+10
# 12      ...       2.400500e+09  2.430000e+09  2.452800e+09  2.480600e+09
# 13      ...       1.183900e+09  1.185200e+09  2.432300e+09  2.550300e+09
# 14      ...                NaN           NaN           NaN  8.506000e+10
# 15      ...       4.046000e+09  3.960000e+09  3.956000e+09  4.023000e+09
# 16      ...                NaN           NaN           NaN  3.993500e+10
# 17      ...       6.012500e+10  6.126600e+10  6.551900e+10  7.542000e+10
# 18      ...       8.690581e+10  1.131540e+11  1.335885e+11  1.492705e+11
# 19      ...       1.355000e+09  1.320000e+09  1.166000e+09  1.229100e+09
# 20      ...       3.114000e+08  3.169000e+08  3.886000e+08  4.445000e+08
# 21      ...                NaN           NaN           NaN           NaN
# 22      ...       3.413730e+08  3.247580e+08  2.981000e+08  3.004000e+08
# 23      ...       1.886500e+08  2.286600e+08  3.762200e+08  6.811830e+08
# 24      ...       3.453508e+07  3.067450e+07  3.083250e+07  3.043825e+07
# 25      ...                NaN           NaN           NaN           NaN
# 26      ...       2.427360e+09  2.297350e+09  2.799539e+09  3.454102e+09
# 27      ...       5.128300e+10  5.981900e+10  6.178800e+10  6.637900e+10
# 28      ...                NaN           NaN           NaN           NaN
# 29      ...       5.087500e+08  5.327500e+08  5.225000e+08  5.139000e+08
# ..      ...                ...           ...           ...           ...
# 234     ...                NaN           NaN           NaN           NaN
# 235     ...       3.648100e+07  2.638900e+07  2.053000e+07  3.338800e+07
# 236     ...                NaN           NaN           NaN           NaN
# 237     ...                NaN           NaN           NaN           NaN
# 238     ...                NaN           NaN           NaN           NaN
# 239     ...                NaN           NaN           NaN           NaN
# 240     ...       8.761500e+08  9.121000e+08  9.362750e+08  1.085075e+09
# 241     ...       7.626000e+08  8.176000e+08  1.006900e+09  1.064000e+09
# 242     ...       2.534541e+10  2.696018e+10  2.898481e+10  3.225300e+10
# 243     ...                NaN           NaN           NaN           NaN
# 244     ...       2.897775e+11  3.984360e+11  4.833860e+11  5.694675e+11
# 245     ...       5.960050e+11  1.325450e+12  1.620950e+12  1.075550e+12
# 246     ...       2.689900e+10  2.959600e+10  2.935800e+10  3.305800e+10
# 247     ...                NaN           NaN           NaN           NaN
# 248     ...       1.302300e+10  1.515800e+10  1.593100e+10  1.878000e+10
# 249     ...       6.685670e+11  6.981800e+11  7.113380e+11  6.847800e+11
# 250     ...                NaN           NaN           NaN           NaN
# 251     ...                NaN           NaN           NaN           NaN
# 252     ...       8.706900e+09  1.030550e+10  1.534511e+10  2.193911e+10
# 253     ...                NaN           NaN           NaN           NaN
# 254     ...                NaN           NaN           NaN           NaN
# 255     ...       4.098100e+13  4.973900e+13  5.510000e+13  7.000000e+13
# 256     ...                NaN           NaN           NaN           NaN
# 257     ...                NaN           NaN           NaN           NaN
# 258     ...                NaN           NaN           NaN           NaN
# 259     ...       1.959923e+07  2.912822e+07  3.666471e+07  3.377049e+07
# 260     ...       2.882000e+11  3.180000e+11  3.447000e+11  3.470000e+11
# 261     ...       3.044325e+10  3.066250e+10  3.335875e+10  3.685940e+10
# 262     ...       1.115000e+09  1.344100e+09  1.502500e+09  1.782500e+09
# 263     ...                NaN  9.829300e+07  1.984380e+08  3.182720e+08
#
#              2013          2014          2015          2016          2017  \
# 0             NaN           NaN           NaN           NaN           NaN
# 1    1.202767e+10  1.535600e+10  1.219917e+10  1.261483e+10  1.302083e+10
# 2    5.878690e+11  6.730000e+11  4.332150e+11  4.622090e+11  5.081750e+11
# 3    1.902200e+10  1.878800e+10  1.667100e+10  1.625000e+10  1.935200e+10
# 4             NaN           NaN           NaN           NaN           NaN
# 5             NaN           NaN           NaN           NaN           NaN
# 6    8.652800e+10  8.356800e+10           NaN           NaN           NaN
# 7    2.805000e+10  4.020900e+10  5.062100e+10  6.658600e+10  9.403190e+10
# 8    1.821000e+11  1.904110e+11  2.138110e+11  2.072700e+11  2.142180e+11
# 9             NaN           NaN           NaN           NaN           NaN
# 10            NaN           NaN           NaN           NaN           NaN
# 11   2.571500e+10  2.860350e+10  3.200550e+10  3.549500e+10  3.582350e+10
# 12   2.432000e+09  2.491200e+09  2.403400e+09  2.609600e+09  2.647100e+09
# 13   2.642000e+09  2.688100e+09  2.971800e+09  2.228800e+09  2.642100e+09
# 14   9.464200e+10  9.616900e+10  1.040040e+11  1.098500e+11  1.098500e+11
# 15   3.964000e+09  3.913000e+09  3.789000e+09  3.901000e+09  3.965000e+09
# 16   4.248900e+10  4.597600e+10  5.376049e+10  4.718700e+10  6.789800e+10
# 17   8.207800e+10  8.759400e+10  8.749600e+10  8.862500e+10  1.116990e+11
# 18   1.599545e+11  1.829225e+11  2.194425e+11  2.544750e+11  2.884030e+11
# 19   1.325600e+09  1.232000e+09  1.166000e+09  1.336000e+09  1.508000e+09
# 20   5.067000e+08  5.547000e+08  5.422000e+08  5.660810e+08  5.252000e+08
# 21            NaN           NaN           NaN           NaN           NaN
# 22   2.911000e+08  2.806530e+08  2.860660e+08  2.908710e+08  2.856890e+08
# 23   8.623486e+08  1.033480e+09  1.152500e+09  1.200300e+09  1.222851e+09
# 24   3.555775e+07  3.983375e+07  3.943525e+07  4.372150e+07  4.558850e+07
# 25            NaN           NaN           NaN           NaN           NaN
# 26   3.900072e+09  4.324866e+09  3.976500e+09  3.818043e+09  4.555274e+09
# 27   7.088100e+10  7.687420e+10  8.187350e+10  8.450900e+10  9.312140e+10
# 28            NaN           NaN           NaN           NaN           NaN
# 29   5.156000e+08  6.687250e+08  5.829925e+08  5.573725e+08  4.798425e+08
# ..            ...           ...           ...           ...           ...
# 234           NaN           NaN           NaN           NaN           NaN
# 235  3.168300e+07  2.962400e+07  3.695900e+07  2.621700e+07  2.544200e+07
# 236           NaN           NaN           NaN           NaN           NaN
# 237           NaN           NaN           NaN           NaN           NaN
# 238           NaN           NaN           NaN           NaN           NaN
# 239           NaN           NaN           NaN           NaN           NaN
# 240  1.360529e+09  1.210587e+09  1.288925e+09  1.433550e+09  1.367550e+09
# 241  1.233700e+09  1.542100e+09  1.921400e+09  2.120120e+09  2.016200e+09
# 242  3.552925e+10  3.889510e+10  4.319612e+10  5.393238e+10  6.556623e+10
# 243           NaN           NaN           NaN           NaN           NaN
# 244  7.096030e+11  8.390530e+11  1.029700e+12  1.185150e+12  1.321328e+12
# 245  1.119350e+12  1.209350e+12  1.569159e+12  1.789078e+12  1.604981e+12
# 246  3.506100e+10  4.794300e+10  7.901000e+10  8.751000e+10  9.669114e+10
# 247           NaN           NaN           NaN           NaN           NaN
# 248  2.140500e+10  2.404800e+10  2.650500e+10  2.977300e+10  3.558400e+10
# 249  6.397040e+11  6.099140e+11  5.961046e+11  6.001064e+11  6.097580e+11
# 250           NaN           NaN           NaN           NaN           NaN
# 251           NaN           NaN           NaN           NaN           NaN
# 252  3.749553e+10  3.521748e+10  5.672101e+10  1.078443e+11  9.698638e+11
# 253           NaN           NaN           NaN           NaN           NaN
# 254           NaN           NaN           NaN           NaN           NaN
# 255  7.802400e+13  9.000000e+13  9.900000e+13  1.100000e+14  1.135340e+14
# 256           NaN           NaN           NaN           NaN           NaN
# 257           NaN           NaN           NaN           NaN           NaN
# 258           NaN           NaN           NaN           NaN           NaN
# 259  3.660178e+07  4.038172e+07  4.507072e+07  4.696200e+07  5.103600e+07
# 260  3.543000e+11  3.685000e+11           NaN           NaN           NaN
# 261  3.976155e+10  4.225475e+10  4.451825e+10  4.669575e+10  4.827335e+10
# 262  2.057700e+09  2.729418e+09  3.215100e+09  3.088700e+09  3.204640e+09
# 263  3.567000e+08  3.681000e+08  3.766770e+08  3.580650e+08  3.405220e+08
#
#      Unnamed: 62
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 7            NaN
# 8            NaN
# 9            NaN
# 10           NaN
# 11           NaN
# 12           NaN
# 13           NaN
# 14           NaN
# 15           NaN
# 16           NaN
# 17           NaN
# 18           NaN
# 19           NaN
# 20           NaN
# 21           NaN
# 22           NaN
# 23           NaN
# 24           NaN
# 25           NaN
# 26           NaN
# 27           NaN
# 28           NaN
# 29           NaN
# ..           ...
# 234          NaN
# 235          NaN
# 236          NaN
# 237          NaN
# 238          NaN
# 239          NaN
# 240          NaN
# 241          NaN
# 242          NaN
# 243          NaN
# 244          NaN
# 245          NaN
# 246          NaN
# 247          NaN
# 248          NaN
# 249          NaN
# 250          NaN
# 251          NaN
# 252          NaN
# 253          NaN
# 254          NaN
# 255          NaN
# 256          NaN
# 257          NaN
# 258          NaN
# 259          NaN
# 260          NaN
# 261          NaN
# 262          NaN
# 263          NaN
#
# [264 rows x 63 columns]

# %% [markdown]
# ## Viewing Data

# %%
expenditures.head()
# Out:
#   Country Name Country Code                      Indicator Name  \
# 0        Aruba          ABW  Military expenditure (current LCU)
# 1  Afghanistan          AFG  Military expenditure (current LCU)
# 2       Angola          AGO  Military expenditure (current LCU)
# 3      Albania          ALB  Military expenditure (current LCU)
# 4      Andorra          AND  Military expenditure (current LCU)
#
#    Indicator Code  1960  1961  1962  1963  1964  1965     ...       \
# 0  MS.MIL.XPND.CN   NaN   NaN   NaN   NaN   NaN   NaN     ...
# 1  MS.MIL.XPND.CN   NaN   NaN   NaN   NaN   NaN   NaN     ...
# 2  MS.MIL.XPND.CN   NaN   NaN   NaN   NaN   NaN   NaN     ...
# 3  MS.MIL.XPND.CN   NaN   NaN   NaN   NaN   NaN   NaN     ...
# 4  MS.MIL.XPND.CN   NaN   NaN   NaN   NaN   NaN   NaN     ...
#
#            2009          2010          2011          2012          2013  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1  1.267533e+10  1.384967e+10  1.523050e+10  1.214900e+10  1.202767e+10
# 2  2.626710e+11  3.217430e+11  3.418750e+11  3.956800e+11  5.878690e+11
# 3  1.735600e+10  1.932100e+10  1.987700e+10  1.982000e+10  1.902200e+10
# 4           NaN           NaN           NaN           NaN           NaN
#
#            2014          2015          2016          2017  Unnamed: 62
# 0           NaN           NaN           NaN           NaN          NaN
# 1  1.535600e+10  1.219917e+10  1.261483e+10  1.302083e+10          NaN
# 2  6.730000e+11  4.332150e+11  4.622090e+11  5.081750e+11          NaN
# 3  1.878800e+10  1.667100e+10  1.625000e+10  1.935200e+10          NaN
# 4           NaN           NaN           NaN           NaN          NaN
#
# [5 rows x 63 columns]

# %%
expenditures.tail()
# Out:
#      Country Name Country Code                      Indicator Name  \
# 259        Kosovo          XKX  Military expenditure (current LCU)
# 260   Yemen, Rep.          YEM  Military expenditure (current LCU)
# 261  South Africa          ZAF  Military expenditure (current LCU)
# 262        Zambia          ZMB  Military expenditure (current LCU)
# 263      Zimbabwe          ZWE  Military expenditure (current LCU)
#
#      Indicator Code        1960        1961         1962         1963  \
# 259  MS.MIL.XPND.CN         NaN         NaN          NaN          NaN
# 260  MS.MIL.XPND.CN         NaN         NaN          NaN          NaN
# 261  MS.MIL.XPND.CN  50000000.0  81250000.0  133000000.0  135000000.0
# 262  MS.MIL.XPND.CN         NaN         NaN          NaN          NaN
# 263  MS.MIL.XPND.CN         NaN         NaN          NaN          NaN
#
#             1964         1965     ...               2009          2010  \
# 259          NaN          NaN     ...       1.959923e+07  2.912822e+07
# 260          NaN          NaN     ...       2.882000e+11  3.180000e+11
# 261  194000000.0  206750000.0     ...       3.044325e+10  3.066250e+10
# 262          NaN          NaN     ...       1.115000e+09  1.344100e+09
# 263          NaN   15600000.0     ...                NaN  9.829300e+07
#
#              2011          2012          2013          2014          2015  \
# 259  3.666471e+07  3.377049e+07  3.660178e+07  4.038172e+07  4.507072e+07
# 260  3.447000e+11  3.470000e+11  3.543000e+11  3.685000e+11           NaN
# 261  3.335875e+10  3.685940e+10  3.976155e+10  4.225475e+10  4.451825e+10
# 262  1.502500e+09  1.782500e+09  2.057700e+09  2.729418e+09  3.215100e+09
# 263  1.984380e+08  3.182720e+08  3.567000e+08  3.681000e+08  3.766770e+08
#
#              2016          2017  Unnamed: 62
# 259  4.696200e+07  5.103600e+07          NaN
# 260           NaN           NaN          NaN
# 261  4.669575e+10  4.827335e+10          NaN
# 262  3.088700e+09  3.204640e+09          NaN
# 263  3.580650e+08  3.405220e+08          NaN
#
# [5 rows x 63 columns]

# %%
expenditures.index
# Out:
# RangeIndex(start=0, stop=264, step=1)

# %%
expenditures.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', 'Unnamed: 62'],
#       dtype='object')

# %%
expenditures.values
# Out:
# array([['Aruba', 'ABW', 'Military expenditure (current LCU)', ..., nan,
#         nan, nan],
#        ['Afghanistan', 'AFG', 'Military expenditure (current LCU)', ...,
#         12614833333.3333, 13020833333.3333, nan],
#        ['Angola', 'AGO', 'Military expenditure (current LCU)', ...,
#         462209000000.0, 508175000000.0, nan],
#        ...,
#        ['South Africa', 'ZAF', 'Military expenditure (current LCU)', ...,
#         46695750000.0, 48273350000.0, nan],
#        ['Zambia', 'ZMB', 'Military expenditure (current LCU)', ...,
#         3088700000.0, 3204640000.0, nan],
#        ['Zimbabwe', 'ZWE', 'Military expenditure (current LCU)', ...,
#         358065000.0, 340522000.0, nan]], dtype=object)

# %% [markdown]
# ## Selection of Data in a `DataFrame`
#
# ### Selection by Column Name

# %%
expenditures['Country Name']
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### Selection by Indexes
#
# In the following we index the third row directly.

# %%
expenditures.iloc[3]
# Out:
# Country Name                                 Albania
# Country Code                                     ALB
# Indicator Name    Military expenditure (current LCU)
# Indicator Code                        MS.MIL.XPND.CN
# 1960                                             NaN
# 1961                                             NaN
# 1962                                             NaN
# 1963                                             NaN
# 1964                                             NaN
# 1965                                             NaN
# 1966                                             NaN
# 1967                                             NaN
# 1968                                             NaN
# 1969                                             NaN
# 1970                                             NaN
# 1971                                             NaN
# 1972                                             NaN
# 1973                                             NaN
# 1974                                             NaN
# 1975                                        6.53e+08
# 1976                                        7.83e+08
# 1977                                        8.05e+08
# 1978                                        8.25e+08
# 1979                                        8.85e+08
# 1980                                         9.4e+08
# 1981                                         9.4e+08
# 1982                                        9.35e+08
# 1983                                         9.1e+08
# 1984                                        1.01e+09
# 1985                                        9.53e+08
#                                  ...
# 1989                                        9.65e+08
# 1990                                         9.9e+08
# 1991                                         9.5e+08
# 1992                                       2.368e+09
# 1993                                        4.01e+09
# 1994                                       4.698e+09
# 1995                                       4.719e+09
# 1996                                       4.777e+09
# 1997                                       4.442e+09
# 1998                                       5.067e+09
# 1999                                       5.891e+09
# 2000                                       6.519e+09
# 2001                                       7.638e+09
# 2002                                        8.22e+09
# 2003                                       9.279e+09
# 2004                                     1.03728e+10
# 2005                                     1.09998e+10
# 2006                                      1.3831e+10
# 2007                                      1.7619e+10
# 2008                                       2.145e+10
# 2009                                      1.7356e+10
# 2010                                      1.9321e+10
# 2011                                      1.9877e+10
# 2012                                       1.982e+10
# 2013                                      1.9022e+10
# 2014                                      1.8788e+10
# 2015                                      1.6671e+10
# 2016                                       1.625e+10
# 2017                                      1.9352e+10
# Unnamed: 62                                      NaN
# Name: 3, Length: 63, dtype: object

# %%
expenditures.loc[3]
# Out:
# Country Name                                 Albania
# Country Code                                     ALB
# Indicator Name    Military expenditure (current LCU)
# Indicator Code                        MS.MIL.XPND.CN
# 1960                                             NaN
# 1961                                             NaN
# 1962                                             NaN
# 1963                                             NaN
# 1964                                             NaN
# 1965                                             NaN
# 1966                                             NaN
# 1967                                             NaN
# 1968                                             NaN
# 1969                                             NaN
# 1970                                             NaN
# 1971                                             NaN
# 1972                                             NaN
# 1973                                             NaN
# 1974                                             NaN
# 1975                                        6.53e+08
# 1976                                        7.83e+08
# 1977                                        8.05e+08
# 1978                                        8.25e+08
# 1979                                        8.85e+08
# 1980                                         9.4e+08
# 1981                                         9.4e+08
# 1982                                        9.35e+08
# 1983                                         9.1e+08
# 1984                                        1.01e+09
# 1985                                        9.53e+08
#                                  ...
# 1989                                        9.65e+08
# 1990                                         9.9e+08
# 1991                                         9.5e+08
# 1992                                       2.368e+09
# 1993                                        4.01e+09
# 1994                                       4.698e+09
# 1995                                       4.719e+09
# 1996                                       4.777e+09
# 1997                                       4.442e+09
# 1998                                       5.067e+09
# 1999                                       5.891e+09
# 2000                                       6.519e+09
# 2001                                       7.638e+09
# 2002                                        8.22e+09
# 2003                                       9.279e+09
# 2004                                     1.03728e+10
# 2005                                     1.09998e+10
# 2006                                      1.3831e+10
# 2007                                      1.7619e+10
# 2008                                       2.145e+10
# 2009                                      1.7356e+10
# 2010                                      1.9321e+10
# 2011                                      1.9877e+10
# 2012                                       1.982e+10
# 2013                                      1.9022e+10
# 2014                                      1.8788e+10
# 2015                                      1.6671e+10
# 2016                                       1.625e+10
# 2017                                      1.9352e+10
# Unnamed: 62                                      NaN
# Name: 3, Length: 63, dtype: object

# %%
expenditures.iloc[3:5]
# Out:
#   Country Name Country Code                      Indicator Name  \
# 3      Albania          ALB  Military expenditure (current LCU)
# 4      Andorra          AND  Military expenditure (current LCU)
#
#    Indicator Code  1960  1961  1962  1963  1964  1965     ...       \
# 3  MS.MIL.XPND.CN   NaN   NaN   NaN   NaN   NaN   NaN     ...
# 4  MS.MIL.XPND.CN   NaN   NaN   NaN   NaN   NaN   NaN     ...
#
#            2009          2010          2011          2012          2013  \
# 3  1.735600e+10  1.932100e+10  1.987700e+10  1.982000e+10  1.902200e+10
# 4           NaN           NaN           NaN           NaN           NaN
#
#            2014          2015          2016          2017  Unnamed: 62
# 3  1.878800e+10  1.667100e+10  1.625000e+10  1.935200e+10          NaN
# 4           NaN           NaN           NaN           NaN          NaN
#
# [2 rows x 63 columns]

# %%
expenditures.iloc[3:5, 4:-1]
# Out:
#    1960  1961  1962  1963  1964  1965  1966  1967  1968  1969      ...       \
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN      ...
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN      ...
#
#            2008          2009          2010          2011          2012  \
# 3  2.145000e+10  1.735600e+10  1.932100e+10  1.987700e+10  1.982000e+10
# 4           NaN           NaN           NaN           NaN           NaN
#
#            2013          2014          2015          2016          2017
# 3  1.902200e+10  1.878800e+10  1.667100e+10  1.625000e+10  1.935200e+10
# 4           NaN           NaN           NaN           NaN           NaN
#
# [2 rows x 58 columns]

# %% [markdown]
# ## Boolean Indexing
#
# Similar to NumPy, you can use boolean arrays for indexing. That is, you can use boolean expressions directly for indexing.
#
# In the following we assign `expenditures` to `df`as the latter is shorter.

# %%
df = expenditures

df[df['Country Name'] == 'Denmark']
# Out:
#    Country Name Country Code                      Indicator Name  \
# 56      Denmark          DNK  Military expenditure (current LCU)
#
#     Indicator Code          1960          1961          1962          1963  \
# 56  MS.MIL.XPND.CN  1.113000e+09  1.180000e+09  1.551000e+09  1.651000e+09
#
#             1964          1965     ...               2009          2010  \
# 56  1.764000e+09  1.974000e+09     ...       2.325200e+10  2.532800e+10
#
#             2011          2012          2013          2014          2015  \
# 56  2.425900e+10  2.561700e+10  2.368200e+10  2.276900e+10  2.263300e+10
#
#             2016          2017  Unnamed: 62
# 56  2.419000e+10  2.516500e+10          NaN
#
# [1 rows x 63 columns]

# %% [markdown]
# Using the `isin()` method for filtering:

# %%
df[df['Country Name'].isin(['United States', 'China', 'Denmark', 'Russian Federation'])]
# Out:
#            Country Name Country Code                      Indicator Name  \
# 38                China          CHN  Military expenditure (current LCU)
# 56              Denmark          DNK  Military expenditure (current LCU)
# 200  Russian Federation          RUS  Military expenditure (current LCU)
# 249       United States          USA  Military expenditure (current LCU)
#
#      Indicator Code          1960          1961          1962          1963  \
# 38   MS.MIL.XPND.CN           NaN           NaN           NaN           NaN
# 56   MS.MIL.XPND.CN  1.113000e+09  1.180000e+09  1.551000e+09  1.651000e+09
# 200  MS.MIL.XPND.CN           NaN           NaN           NaN           NaN
# 249  MS.MIL.XPND.CN  4.538000e+10  4.780800e+10  5.238100e+10  5.229500e+10
#
#              1964          1965     ...               2009          2010  \
# 38            NaN           NaN     ...       7.217000e+11  7.834000e+11
# 56   1.764000e+09  1.974000e+09     ...       2.325200e+10  2.532800e+10
# 200           NaN           NaN     ...       1.635650e+12  1.783210e+12
# 249  5.121300e+10  5.182700e+10     ...       6.685670e+11  6.981800e+11
#
#              2011          2012          2013          2014          2015  \
# 38   8.914702e+11  9.935000e+11  1.114496e+12  1.233430e+12  1.333262e+12
# 56   2.425900e+10  2.561700e+10  2.368200e+10  2.276900e+10  2.263300e+10
# 200  2.063740e+12  2.512500e+12  2.812900e+12  3.250500e+12  4.047400e+12
# 249  7.113380e+11  6.847800e+11  6.397040e+11  6.099140e+11  5.961046e+11
#
#              2016          2017  Unnamed: 62
# 38   1.436617e+12  1.544163e+12          NaN
# 56   2.419000e+10  2.516500e+10          NaN
# 200  4.644800e+12  3.868700e+12          NaN
# 249  6.001064e+11  6.097580e+11          NaN
#
# [4 rows x 63 columns]

# %% [markdown]
# Here, we create a `DataFrame` of all country codes for the four countries, which we want to study further in the following.

# %%
c_code_df = df[df['Country Name'].isin(['United States', 'China', 
                                        'Denmark', 'Russian Federation'])]['Country Code']
c_code_df
# Out:
# 38     CHN
# 56     DNK
# 200    RUS
# 249    USA
# Name: Country Code, dtype: object

# %% [markdown]
# We cannot plot the time series of military expenditures directly in a meaningful way as we would like to have the years on the y-axis but in the selection of our `DataFrame`, the year numbers are column names. Consequently, we have to transpose our `DataFrame`, see `T` function.
#
# Note, that the expenditures are given in `LUC` in the World Bank data set. That is, in currency of the corresponding country.

# %%
import matplotlib.pyplot as plt

ts_df = df.iloc[c_code_df.index, 31:-1].T
ts_df = ts_df.rename(columns=dict(c_code_df))
ts_df
ts_df.plot()

# %% [markdown]
# Since this plot may be a bit misleading, we will 'normalize' all expeditures to Euro, so that they are better comparible.

# %%
import requests


# http://www.ecb.europa.eu/stats/policy_and_exchange_rates/euro_reference_exchange_rates/html/index.en.html#dev
response = requests.get('http://www.ecb.europa.eu/stats/eurofxref/eurofxref-daily.xml')
response.text
# Out:
# '<?xml version="1.0" encoding="UTF-8"?>\n<gesmes:Envelope xmlns:gesmes="http://www.gesmes.org/xml/2002-08-01" xmlns="http://www.ecb.int/vocabulary/2002-08-01/eurofxref">\n\t<gesmes:subject>Reference rates</gesmes:subject>\n\t<gesmes:Sender>\n\t\t<gesmes:name>European Central Bank</gesmes:name>\n\t</gesmes:Sender>\n\t<Cube>\n\t\t<Cube time=\'2018-10-01\'>\n\t\t\t<Cube currency=\'USD\' rate=\'1.1606\'/>\n\t\t\t<Cube currency=\'JPY\' rate=\'132.25\'/>\n\t\t\t<Cube currency=\'BGN\' rate=\'1.9558\'/>\n\t\t\t<Cube currency=\'CZK\' rate=\'25.765\'/>\n\t\t\t<Cube currency=\'DKK\' rate=\'7.4557\'/>\n\t\t\t<Cube currency=\'GBP\' rate=\'0.89078\'/>\n\t\t\t<Cube currency=\'HUF\' rate=\'323.04\'/>\n\t\t\t<Cube currency=\'PLN\' rate=\'4.2796\'/>\n\t\t\t<Cube currency=\'RON\' rate=\'4.6605\'/>\n\t\t\t<Cube currency=\'SEK\' rate=\'10.3300\'/>\n\t\t\t<Cube currency=\'CHF\' rate=\'1.1414\'/>\n\t\t\t<Cube currency=\'ISK\' rate=\'129.30\'/>\n\t\t\t<Cube currency=\'NOK\' rate=\'9.4465\'/>\n\t\t\t<Cube currency=\'HRK\' rate=\'7.4330\'/>\n\t\t\t<Cube currency=\'RUB\' rate=\'76.1229\'/>\n\t\t\t<Cube currency=\'TRY\' rate=\'6.9080\'/>\n\t\t\t<Cube currency=\'AUD\' rate=\'1.6070\'/>\n\t\t\t<Cube currency=\'BRL\' rate=\'4.6869\'/>\n\t\t\t<Cube currency=\'CAD\' rate=\'1.4867\'/>\n\t\t\t<Cube currency=\'CNY\' rate=\'7.9720\'/>\n\t\t\t<Cube currency=\'HKD\' rate=\'9.0848\'/>\n\t\t\t<Cube currency=\'IDR\' rate=\'17304.55\'/>\n\t\t\t<Cube currency=\'ILS\' rate=\'4.2251\'/>\n\t\t\t<Cube currency=\'INR\' rate=\'84.6215\'/>\n\t\t\t<Cube currency=\'KRW\' rate=\'1290.16\'/>\n\t\t\t<Cube currency=\'MXN\' rate=\'21.5632\'/>\n\t\t\t<Cube currency=\'MYR\' rate=\'4.8049\'/>\n\t\t\t<Cube currency=\'NZD\' rate=\'1.7572\'/>\n\t\t\t<Cube currency=\'PHP\' rate=\'62.733\'/>\n\t\t\t<Cube currency=\'SGD\' rate=\'1.5903\'/>\n\t\t\t<Cube currency=\'THB\' rate=\'37.418\'/>\n\t\t\t<Cube currency=\'ZAR\' rate=\'16.4326\'/>\n\t\t</Cube>\n\t</Cube>\n</gesmes:Envelope>'

# %%
from bs4 import BeautifulSoup


xml = BeautifulSoup(response.text, 'html5lib')
rate_list = xml.cube.cube.findAll("cube") # [0]['rate']

currency = ['USD', 'DKK', 'RUB', 'CNY']
rate_dict = dict.fromkeys(currency)
for r in rate_list:
    if r['currency'] in currency:
        rate_dict[r['currency']] = float(r['rate'])
        print(r['rate'])
rate_dict
# Out:
# 1.1576
# 7.4564
# 76.1422
# 7.9662
# {'CNY': 7.9662, 'DKK': 7.4564, 'RUB': 76.1422, 'USD': 1.1576}

# %%
ts_df['DNK'] = ts_df['DNK'] / rate_dict['DKK']
ts_df['USA'] = ts_df['USA'] / rate_dict['USD']
ts_df['CHN'] = ts_df['CHN'] / rate_dict['CNY']
ts_df['RUS'] = ts_df['RUS'] / rate_dict['RUB']
ts_df.plot()

# %% [markdown]
# **OBS!!!** Be careful, the graph above is still not really well suited for comparison as currency exchange rates are not fix. However, the code above normalizes just relying on the most current exchange rate from the European Central Bank. See the exercise block in the bottom for how to fix that isuue!

# %% [markdown]
# # Exercises for the Interested
#
#   * Complete the comparison of military expenditures by converting all currencies to USD. Since we have yearly expenditures, use for example the yearly median for normalization. Likely, you will find an API to collect historical echange rates at Yahoo Finance.
#
#   https://developer.yahoo.com/yql/console/?q=show%20tables&env=store://datatables.org/alltableswithkeys#h=select+*+from+yahoo.finance.historicaldata+where+symbol+%3D+%22RUB%3DX%22+and+startDate+%3D+%222010-01-01%22+and+endDate+%3D+%222011-01-01%22

# %% [markdown]
# ## PS
#
# In case you have to sort the data in your `DataFrames` see the methods `sort_index` and `sort_values`.
#
#
# ```python
# df.sort_index(axis=1, ascending=True)
# df.sort_values(by='Country Code')
# ```

# %%
df.sort_index?

# %%
df.sort_values?
